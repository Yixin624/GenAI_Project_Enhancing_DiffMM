# %%
# If you need GPU version of PyTorch, uncomment the following
# # Uninstall CPU version (if any)
# # !python -m pip uninstall -y torch

# # Install GPU version (CUDA 11.3, corresponding to official wheel for 1.11.0)
# !python -m pip install \
#   torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 \
#   --extra-index-url https://download.pytorch.org/whl/cu113

# Check current PyTorch version
# !python -V
# !python -c "import torch; print(f'torch version: {torch.__version__}'); print(f'CUDA available: {torch.cuda.is_available()}')"
# Out:
# Python 3.10.13
# torch version: 2.1.0+cu121
# CUDA available: True

# %%
# Wandb login setup
import wandb
import os

# Enter your Wandb API Key here
# How to get it: https://wandb.ai/settings -> API keys
WANDB_API_KEY = 'dbcb5b22a7512074ad91148adc5794d1955289ad'  # Your API key

# Set environment variable (wandb will automatically read it)
if WANDB_API_KEY:
    os.environ['WANDB_API_KEY'] = WANDB_API_KEY
    print("✅ API Key has been set to environment variable")

# Verify login status
try:
    # Try to verify using API
    api = wandb.Api()
    
    # Check if already logged in
    try:
        if hasattr(api, 'viewer'):
            user = api.viewer()
            print(f"✅ Current logged-in user: {user.username}")
            print(f"✅ Workspace: {user.username}")
            print(f"✅ All runs will be logged to: https://wandb.ai/{user.username}/enhancing_diffmm")
        else:
            # Try another way to get user information
            print("✅ Wandb is configured, all runs will be logged to your personal workspace")
    except Exception as e:
        print(f"✅ Wandb is configured (unable to get user info, but this doesn't affect usage)")
        print(f"   All runs will be logged to your personal workspace")
        
except Exception as e:
    print(f"⚠️ Unable to verify wandb configuration: {e}")
    print("   But API key is set, should work normally during training")
    print("   If you encounter problems, you can run: !wandb login")
# Out:
# ✅ API Key已设置到环境变量
# ⚠️ 无法验证wandb配置: module 'wandb' has no attribute 'Api'
#    但API key已设置，训练时应该可以正常使用
#    如果遇到问题，可以运行: !wandb login

# %% [markdown]
# # Wandb Login
# **Important**: Set your Wandb API Key in the cell above to ensure all runs are logged to your personal workspace.
#
# # Dataset download

# %% [markdown]
# tiktok   !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 50 --trans 1 --e_loss 0.1 --cl_method 1

# %%
# Run Main.py (make sure you're in the DiffMM directory)
import os
if not os.path.basename(os.getcwd()) == 'DiffMM_Code/DiffMM':
    os.chdir('DiffMM_Code/DiffMM')
print(f"Current working directory: {os.getcwd()}")
# Out:
# 当前工作目录: /jet/home/ygao8/DiffMM_Code/DiffMM

# %%
#tiktok (original version)
# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 50 --trans 1 --e_loss 0.1 --cl_method 1 --run_name "tiktok_original_epoch50——timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_192144-prgbcswq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_original_epoch50——timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/prgbcswq
# 2025-12-08 19:21:45.360936: Start
# 2025-12-08 19:21:45.755707: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# 2025-12-08 19:21:46.578549: Model Prepared
# 2025-12-08 19:21:46.578852: Model Initialized
# 2025-12-08 19:21:47.328844: Diffusion Step 9/9
# 2025-12-08 19:21:47.328937: Start to re-build UI matrix
# ...

# %%
#tiktok with transformer fusion (2 layers, 4 heads)
# Use Transformer for multi-modal fusion, replacing the original weighted sum
# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 50 --trans 1 --e_loss 0.1 --cl_method 1 --use_transformer_fusion --transformer_layers 2 --transformer_heads 4 --run_name "tiktok_transformer_layer2_head4"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_173438-6g6lsz6w
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_layer2_head4
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/6g6lsz6w
# 2025-12-08 17:34:39.151175: Start
# 2025-12-08 17:34:39.530365: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# 2025-12-08 17:34:40.336530: Model Prepared
# 2025-12-08 17:34:40.336826: Model Initialized
# 2025-12-08 17:34:40.995616: Diffusion Step 9/9
# 2025-12-08 17:34:40.995736: Start to re-build UI matrix
# ...

# %%
#tiktok with transformer fusion + latent space
# Use both Transformer fusion and Latent space
# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 50 --trans 1 --e_loss 0.1 --cl_method 1 --use_transformer_fusion --transformer_layers 2 --transformer_heads 4 --use_latent_space --latent_dim 128 --run_name "tiktok_transformer_layer2_head4_latent128"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_174141-xkwkzr1o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_layer2_head4_latent128
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/xkwkzr1o
# 2025-12-08 17:41:42.192930: Start
# 2025-12-08 17:41:42.567474: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0001
# 2025-12-08 17:41:44.546601: Model Prepared
# 2025-12-08 17:41:44.547047: Model Initialized
# 2025-12-08 17:41:45.632119: Diffusion Step 9/9
# ...

# %%
#tiktok with latent space
# You can customize run name, for example: --run_name "my_experiment_v1"
# If --run_name is not specified, it will auto-generate: tiktok_lat64_gnn1_latent128
# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 50 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 64 --run_name "tiktok_latent_epoch50_dim64_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_193505-43rnsqij
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_latent_epoch50_dim64_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/43rnsqij
# 2025-12-08 19:35:06.175480: Start
# 2025-12-08 19:35:06.552637: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# 2025-12-08 19:35:08.457827: Model Prepared
# 2025-12-08 19:35:08.458307: Model Initialized
# 2025-12-08 19:35:09.519350: Diffusion Step 9/9
# 2025-12-08 19:35:09.519439: Start to re-build UI matrix
# ...

# %% [markdown]
# baby   ======    !python Main.py --data baby --reg 1e-5 --ssl_reg 1e-1 --keepRate 1 --e_loss 0.01

# %%
# baby
# !python Main.py --data baby --reg 1e-5 --ssl_reg 1e-1 --epoch 50 --keepRate 1 --e_loss 0.01 --run_name "baby_original_epoch50_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_200137-ipkcq0q6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run baby_original_epoch50_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/ipkcq0q6
# 2025-12-08 20:01:37.851453: Start
# 2025-12-08 20:01:38.755658: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2025-12-08 20:01:39.462877: Model Prepared
# 2025-12-08 20:01:39.463126: Model Initialized
# 2025-12-08 20:01:40.459349: Diffusion Step 18/18
# 2025-12-08 20:01:40.459446: Start to re-build UI matrix
# ...

# %%
# baby with latent space
# !python Main.py --data baby --reg 1e-5 --ssl_reg 1e-1 --epoch 50 --keepRate 1 --e_loss 0.01 --use_latent_space --latent_dim 128 --run_name "baby_latent_epoch50_dim128_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_200946-wqvt1cw0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run baby_latent_epoch50_dim128_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/wqvt1cw0
# 2025-12-08 20:09:47.021112: Start
# 2025-12-08 20:09:47.735452: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2025-12-08 20:09:49.285687: Model Prepared
# 2025-12-08 20:09:49.286120: Model Initialized
# 2025-12-08 20:09:50.902214: Diffusion Step 18/18
# 2025-12-08 20:09:50.902318: Start to re-build UI matrix
# ...

# %% [markdown]
# sports  !python Main.py --data sports --reg 1e-6 --ssl_reg 1e-2 --temp 0.1 --ris_lambda 0.1 --e_loss 0.5 --keepRate 1 --trans 1

# %%
# !python Main.py --data sports --reg 1e-6 --ssl_reg 1e-2 --epoch 50 --temp 0.1 --ris_lambda 0.1 --e_loss 0.5 --keepRate 1 --trans 1 --run_name "sports_original_epoch50_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_201815-zot0hzu9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sports_original_epoch50_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/zot0hzu9
# 2025-12-08 20:18:16.058912: Start
# 2025-12-08 20:18:17.767637: Load Data
# USER 35598 ITEM 18357
# NUM OF INTERACTIONS 218409
# 2025-12-08 20:18:18.976893: Model Prepared
# 2025-12-08 20:18:18.977207: Model Initialized
# 2025-12-08 20:18:22.158147: Diffusion Step 34/34
# 2025-12-08 20:18:22.158258: Start to re-build UI matrix
# ...

# %%
# sports with latent space
# !python Main.py --data sports --reg 1e-6 --ssl_reg 1e-2 --epoch 50 --temp 0.1 --ris_lambda 0.1 --e_loss 0.5 --keepRate 1 --trans 1 --use_latent_space --latent_dim 128 --run_name "sports_latent_epoch50"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_204141-hs6tn8y8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sports_latent_epoch50
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/hs6tn8y8
# 2025-12-08 20:41:42.080676: Start
# 2025-12-08 20:41:43.292875: Load Data
# USER 35598 ITEM 18357
# NUM OF INTERACTIONS 218409
# 2025-12-08 20:41:51.305499: Model Prepared
# 2025-12-08 20:41:51.305839: Model Initialized
# 2025-12-08 20:42:04.108861: Diffusion Step 34/34
# 2025-12-08 20:42:04.108962: Start to re-build UI matrix
# ...

# %%
# Extract sports dataset
# !unzip -o Datasets/sports.zip -d Datasets/sports

# Move files to correct location (if there are nested directories after extraction)
import os
sports_dir = "Datasets/sports"
if os.path.exists(os.path.join(sports_dir, "sports")):
    # !mv {sports_dir}/sports/* {sports_dir}/
    # !rm -r {sports_dir}/sports
# Out:
# unzip:  cannot find or open Datasets/sports.zip, Datasets/sports.zip.zip or Datasets/sports.zip.ZIP.

# %%
# !python Main.py --data sports --reg 1e-6 --ssl_reg 1e-2 --epoch 2 --temp 0.1 --ris_lambda 0.1 --e_loss 0.5 --keepRate 1 --trans 1
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: deep-learning-hw-ablations to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251207_200023-mbw6t99s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sports_lat64_gnn1
# wandb: ⭐️ View project at https://wandb.ai/deep-learning-hw-ablations/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/deep-learning-hw-ablations/enhancing_diffmm/runs/mbw6t99s
# 2025-12-07 20:00:24.381976: Start
# 2025-12-07 20:00:26.212147: Load Data
# USER 35598 ITEM 18357
# NUM OF INTERACTIONS 218409
# 2025-12-07 20:00:27.442489: Model Prepared
# 2025-12-07 20:00:27.442994: Model Initialized
# 2025-12-07 20:00:30.659460: Diffusion Step 34/34
# ...

# %%
#tiktok with latent space dim16
# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 50 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 16 --run_name "tiktok_latent_dim32_epoch50"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_171332-ls5p29h6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_latent_dim32_epoch50
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/ls5p29h6
# 2025-12-08 17:13:33.554665: Start
# 2025-12-08 17:13:33.936013: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# 2025-12-08 17:13:35.850454: Model Prepared
# 2025-12-08 17:13:35.850974: Model Initialized
# 2025-12-08 17:13:36.901210: Diffusion Step 9/9
# 2025-12-08 17:13:36.901303: Start to re-build UI matrix
# ...

# %%
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_lr_scale 0.1 \
    --transformer_grad_clip 1.0 \
    --run_name "tiktok_transformer_stable"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_174816-6c3pv8es
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_stable
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/6c3pv8es
# 2025-12-08 17:48:17.216402: Start
# 2025-12-08 17:48:17.604945: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0001
# 2025-12-08 17:48:18.415178: Model Prepared
# 2025-12-08 17:48:18.415473: Model Initialized
# 2025-12-08 17:48:19.063411: Diffusion Step 9/9
# ...

# %%
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_dropout 0.2 \
    --transformer_lr_scale 0.05 \
    --transformer_grad_clip 0.5 \
    --run_name "tiktok_transformer_v2_stable"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_175720-t5q8rnwm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_v2_stable
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/t5q8rnwm
# 2025-12-08 17:57:20.750147: Start
# 2025-12-08 17:57:21.146911: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=5e-05
# 2025-12-08 17:57:21.980346: Model Prepared
# 2025-12-08 17:57:21.980684: Model Initialized
# 2025-12-08 17:57:22.703519: Diffusion Step 9/9
# ...

# %%
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_dropout 0.2 \
    --transformer_lr_scale 0.2 \
    --transformer_grad_clip 1.0 \
    --run_name "tiktok_transformer_v3_balanced"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_180536-nzgj0wld
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_v3_balanced
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/nzgj0wld
# 2025-12-08 18:05:37.060196: Start
# 2025-12-08 18:05:37.505865: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0002
# 2025-12-08 18:05:38.357029: Model Prepared
# 2025-12-08 18:05:38.357328: Model Initialized
# 2025-12-08 18:05:39.023058: Diffusion Step 9/9
# ...

# %%
# Change to mixed strategy
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_dropout 0.2 \
    --transformer_lr_scale 0.2 \
    --transformer_grad_clip 1.0 \
    --transformer_mix_weight 0.1 \
    --run_name "tiktok_transformer_mixed_0.1"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_181944-kplnm0oz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_mixed_0.3
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/kplnm0oz
# 2025-12-08 18:19:45.418165: Start
# 2025-12-08 18:19:45.814261: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0002
# 2025-12-08 18:19:46.626324: Model Prepared
# 2025-12-08 18:19:46.626627: Model Initialized
# 2025-12-08 18:19:47.285683: Diffusion Step 9/9
# ...

# %%
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_dropout 0.1 \
    --transformer_lr_scale 0.3 \
    --transformer_grad_clip 1.0 \
    --run_name "tiktok_transformer_residual"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_183248-dulva5n3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_residual
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/dulva5n3
# 2025-12-08 18:32:48.577213: Start
# 2025-12-08 18:32:48.990620: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0003
# 2025-12-08 18:32:49.795458: Model Prepared
# 2025-12-08 18:32:49.795769: Model Initialized
# 2025-12-08 18:32:50.456257: Diffusion Step 9/9
# ...

# %%
# Added feature alignment
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_dropout 0.1 \
    --transformer_lr_scale 0.3 \
    --transformer_grad_clip 1.0 \
    --transformer_align_weight 0.7 \
    --run_name "tiktok_transformer_aligned0.7"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_185149-xdmgjq2o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_aligned0.7
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/xdmgjq2o
# 2025-12-08 18:51:49.806042: Start
# 2025-12-08 18:51:50.208436: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0003
# 2025-12-08 18:51:51.068831: Model Prepared
# 2025-12-08 18:51:51.069133: Model Initialized
# 2025-12-08 18:51:51.809522: Diffusion Step 9/9
# ...

# %%
# trans positional embedding
# !python Main.py --data tiktok \
    --use_transformer_fusion \
    --transformer_layers 2 \
    --transformer_heads 4 \
    --transformer_dropout 0.1 \
    --transformer_lr_scale 0.3 \
    --transformer_grad_clip 1.0 \
    --transformer_align_weight 0.1 \
    --use_latent_space \
    --latent_dim 128 \
    --run_name "tiktok_transformer_aligned_latent128_posemb"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_190905-ml049e1i
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_transformer_aligned_latent128_posemb
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/ml049e1i
# 2025-12-08 19:09:05.909036: Start
# 2025-12-08 19:09:06.296604: Load Data
# USER 9308 ITEM 6710
# NUM OF INTERACTIONS 59541
# Using separate learning rates: Main=0.001, Transformer=0.0003
# 2025-12-08 19:09:08.278436: Model Prepared
# 2025-12-08 19:09:08.278903: Model Initialized
# 2025-12-08 19:09:09.352081: Diffusion Step 9/9
# ...

# %% [markdown]
# ## Final

# %%
# Baby 
# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 25 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 32 --run_name "tiktok_latent_epoch25_dim32_timelog"

# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 25 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 64 --run_name "tiktok_latent_epoch25_dim64_timelog"

# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 25 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 128 --run_name "tiktok_latent_epoch25_dim128_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_211435-qgfo6wb3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_latent_epoch25_dim32_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/qgfo6wb3
# 2025-12-08 21:14:36.020206: Start
# 2025-12-08 21:14:36.937760: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2025-12-08 21:14:38.452980: Model Prepared
# 2025-12-08 21:14:38.453426: Model Initialized
# 2025-12-08 21:14:40.035695: Diffusion Step 18/18
# 2025-12-08 21:14:40.035809: Start to re-build UI matrix
# ...

# %%
# Additional baby experiments
# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 20 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 64 --run_name "tiktok_latent_epoch25_dim64_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_213148-datjzijb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tiktok_latent_epoch25_dim64_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/datjzijb
# 2025-12-08 21:31:49.441360: Start
# 2025-12-08 21:31:50.106634: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2025-12-08 21:31:51.605277: Model Prepared
# 2025-12-08 21:31:51.605631: Model Initialized
# 2025-12-08 21:31:53.166108: Diffusion Step 18/18
# 2025-12-08 21:31:53.166198: Start to re-build UI matrix
# ...

# %%
# Additional baby experiments

# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 20 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 128 --run_name "baby_latent_epoch25_dim128_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_212812-0cnm9500
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run baby_latent_epoch25_dim128_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/0cnm9500
# 2025-12-08 21:28:12.565330: Start
# 2025-12-08 21:28:13.267840: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2025-12-08 21:28:14.816940: Model Prepared
# 2025-12-08 21:28:14.817369: Model Initialized
# 2025-12-08 21:28:16.428324: Diffusion Step 18/18
# 2025-12-08 21:28:16.428438: Start to re-build UI matrix
# ...

# %%
# Additional baby experiments

# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 20 --trans 1 --e_loss 0.1 --cl_method 1 --run_name "baby_epoch25_timelog"

# %%
# sports
# !python Main.py --data sports --reg 1e-4 --ssl_reg 1e-2 --epoch 5 --trans 1 --e_loss 0.1 --cl_method 1 --run_name "sports_original_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: gaoyuanyi-22 (idl-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_213525-gzpfzbju
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sports_original_timelog
# wandb: ⭐️ View project at https://wandb.ai/idl-/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/idl-/enhancing_diffmm/runs/gzpfzbju
# 2025-12-08 21:35:26.075181: Start
# 2025-12-08 21:35:27.280078: Load Data
# USER 35598 ITEM 18357
# NUM OF INTERACTIONS 218409
# 2025-12-08 21:35:28.515845: Model Prepared
# 2025-12-08 21:35:28.516136: Model Initialized
# 2025-12-08 21:35:31.712047: Diffusion Step 34/34
# 2025-12-08 21:35:31.712133: Start to re-build UI matrix
# ...

# %%
# Sports
# !python Main.py --data sports --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 32 --run_name "sports_latent_epoch25_dim32_timelog"
# !python Main.py --data sports --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 64 --run_name "sports_latent_epoch25_dim64_timelog"
# !python Main.py --data sports --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 128 --run_name "sports_latent_epoch25_dim128_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: deep-learning-hw-ablations to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_220323-o98vids2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sports_latent_epoch25_dim32_timelog
# wandb: ⭐️ View project at https://wandb.ai/deep-learning-hw-ablations/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/deep-learning-hw-ablations/enhancing_diffmm/runs/o98vids2
# 2025-12-08 22:03:23.646687: Start
# 2025-12-08 22:03:25.445428: Load Data
# USER 35598 ITEM 18357
# NUM OF INTERACTIONS 218409
# 2025-12-08 22:03:33.652756: Model Prepared
# 2025-12-08 22:03:33.653085: Model Initialized
# 2025-12-08 22:03:46.108495: Diffusion Step 34/34
# ...

# %%
# tiktok timing experiments
# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --run_name "tiktok_original_timelog"

# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 32 --run_name "tiktok_latent_epoch25_dim32_timelog"

# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 64 --run_name "tiktok_latent_epoch25_dim64_timelog"

# !python Main.py --data tiktok --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --use_latent_space --latent_dim 128 --run_name "tiktok_latent_epoch25_dim128_timelog"

# %%
# !python Main.py --data baby --reg 1e-4 --ssl_reg 1e-2 --epoch 10 --trans 1 --e_loss 0.1 --cl_method 1 --run_name "baby_original_timelog"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: deep-learning-hw-ablations to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /jet/home/ygao8/DiffMM_Code/DiffMM/wandb/run-20251208_220140-cn2qmbdn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run baby_original_timelog
# wandb: ⭐️ View project at https://wandb.ai/deep-learning-hw-ablations/enhancing_diffmm
# wandb: 🚀 View run at https://wandb.ai/deep-learning-hw-ablations/enhancing_diffmm/runs/cn2qmbdn
# 2025-12-08 22:01:40.703245: Start
# 2025-12-08 22:01:41.430150: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2025-12-08 22:01:42.091217: Model Prepared
# 2025-12-08 22:01:42.091458: Model Initialized
# 2025-12-08 22:01:43.120764: Diffusion Step 18/18
# ...
